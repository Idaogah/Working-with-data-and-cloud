# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from openai.api_resources import model
import os
import openai

# Set your OpenAI API key
openai.api_key = "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"

# Define a function that takes in a user prompt and returns an OpenAI-generated response
def generate_response(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=60,
        temperature=0.5,
    )
    return response.choices[0].text

# Define a function that prompts the user for input and returns a response generated by the chatbot
def chat():
    print("Hi! I'm a chatbot. How can I help you today?")
    while True:
        prompt = input("You: ")
        if prompt.lower() in ["bye", "goodbye", "exit", "quit"]:
            print("Chatbot: Goodbye!")
            break
        response = generate_response(prompt)
        print("Chatbot:", response)


# print(response.choices[0].text)

# %%
# Call the chat function to start the chatbot
chat()
# Out:
# Hi! I'm a chatbot. How can I help you today?
# You: What is the name of the place where money is kept?
# Chatbot:
#
# A bank.
# You: quit
# Chatbot: Goodbye!

# %% [markdown]
# If you want to integrate the get_all_categories method in the script above, you would need to create a class that contains the method and instantiate that class before calling the method. Here's an example of how you can modify the script to do this in php:
#
#
# ```
# <?php
# class MyClass {
#     public function get_all_categories() {
#         $categories = get_categories(array('hide_empty' => false));
#         return $categories;
#     }
# }
#
# $myObject = new MyClass();
# $categories = $myObject->get_all_categories();
#
# echo '<ul>';
# foreach ($categories as $category) {
#     echo '<li><a href="' . get_category_link($category->term_id) . '">' . $category->name . '</a></li>';
# }
# echo '</ul>';
# ?>
# ```
#
# In this example, the MyClass class contains the get_all_categories method, which returns an array of category objects. The $myObject variable is then used to create a new instance of the MyClass class, and the get_all_categories method is called on that instance.
#
# After getting the list of categories, the code then outputs an unordered list of links to the category archive pages. Note that the code assumes that the get_category_link function is defined elsewhere in the script.
#
# Keep in mind that this is just an example, and the exact implementation will depend on the specifics of your project.
